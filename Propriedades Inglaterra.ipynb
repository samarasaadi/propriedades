# %% [markdown]
# ### Objetivo: organizar de forma separada as informações de tempo (coluna timestamp) e de propriedade (coluna property_type)

# %% [markdown]
# #### 1 - Importar pacotes

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 2 - Pegar dados

# %%
    # Base de dados
df = pd.read_csv('https://raw.githubusercontent.com/OpenClassrooms-Student-Center/Supervised-Learning/master/fe_splitting.csv')
df
# Out:
#                      borough  \
# 0     Kensington And chelsea
# 1                     Camden
# 2                  Southwark
# 3                Westminster
# 4       Barking And dagenham
# ...                      ...
# 1424                  Sutton
# 1425              Hillingdon
# 1426    Richmond Upon thames
# 1427                Hounslow
# 1428                  Bexley
#
#                                           property_type timestamp_of_call
# 0      Purpose Built Flats/Maisonettes - 4 to 9 storeys  01/01/2017 16:48
# 1      Purpose Built Flats/Maisonettes - 4 to 9 storeys  01/01/2017 22:20
# 2      Purpose Built Flats/Maisonettes - 4 to 9 storeys  01/01/2017 09:51
# 3      Purpose Built Flats/Maisonettes - 4 to 9 storeys  01/01/2017 00:28
# 4                              House - single occupancy  01/01/2017 13:33
# ...                                                 ...               ...
# 1424                           House - single occupancy  31/03/2017 14:58
# 1425                           House - single occupancy  31/03/2017 22:41
# 1426  Purpose Built Flats/Maisonettes - Up to 3 storeys  31/03/2017 17:01
# 1427        Converted Flat/Maisonette - Up to 2 storeys  31/03/2017 11:14
# 1428                   Self contained Sheltered Housing  31/03/2017 15:18
#
# [1429 rows x 3 columns]

# %% [markdown]
# #### 3 - Checar os data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1429 entries, 0 to 1428
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   borough            1429 non-null   object
#  1   property_type      1429 non-null   object
#  2   timestamp_of_call  1429 non-null   object
# dtypes: object(3)
# memory usage: 33.6+ KB

# %% [markdown]
# #### 4 - Coluna timestamp_of_call: Mudar o data type da coluna 'timestamp_of_call' para data

# %%
df['timestamp_of_call'] = pd.to_datetime(df['timestamp_of_call'])

    # Checando se o data type mudou
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1429 entries, 0 to 1428
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   borough            1429 non-null   object
#  1   property_type      1429 non-null   object
#  2   timestamp_of_call  1429 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 33.6+ KB

# %% [markdown]
# #### 5 - Coluna timestamp_of_call: Acrescentar novas colunas de tempo ao data frame

# %%
df['dia'] = df['timestamp_of_call'].dt.day
df['mês'] = df['timestamp_of_call'].dt.month
df['ano'] = df['timestamp_of_call'].dt.year
df['dia_semana'] = df['timestamp_of_call'].dt.weekday
df['hora'] = df['timestamp_of_call'].dt.hour

    # Conferindo se alguma coluna ficou com informações vazias
df.isnull().sum()
# Out:
# borough              0
# property_type        0
# timestamp_of_call    0
# dia                  0
# mês                  0
# ano                  0
# dia_semana           0
# hora                 0
# dtype: int64

# %%
df
# Out:
#                      borough  \
# 0     Kensington And chelsea
# 1                     Camden
# 2                  Southwark
# 3                Westminster
# 4       Barking And dagenham
# ...                      ...
# 1424                  Sutton
# 1425              Hillingdon
# 1426    Richmond Upon thames
# 1427                Hounslow
# 1428                  Bexley
#
#                                           property_type   timestamp_of_call  \
# 0      Purpose Built Flats/Maisonettes - 4 to 9 storeys 2017-01-01 16:48:00
# 1      Purpose Built Flats/Maisonettes - 4 to 9 storeys 2017-01-01 22:20:00
# 2      Purpose Built Flats/Maisonettes - 4 to 9 storeys 2017-01-01 09:51:00
# 3      Purpose Built Flats/Maisonettes - 4 to 9 storeys 2017-01-01 00:28:00
# 4                              House - single occupancy 2017-01-01 13:33:00
# ...                                                 ...                 ...
# 1424                           House - single occupancy 2017-03-31 14:58:00
# 1425                           House - single occupancy 2017-03-31 22:41:00
# 1426  Purpose Built Flats/Maisonettes - Up to 3 storeys 2017-03-31 17:01:00
# 1427        Converted Flat/Maisonette - Up to 2 storeys 2017-03-31 11:14:00
# 1428                   Self contained Sheltered Housing 2017-03-31 15:18:00
#
#       dia  mês   ano  dia_semana  hora
# 0       1    1  2017           6    16
# 1       1    1  2017           6    22
# 2       1    1  2017           6     9
# 3       1    1  2017           6     0
# 4       1    1  2017           6    13
# ...   ...  ...   ...         ...   ...
# 1424   31    3  2017           4    14
# 1425   31    3  2017           4    22
# 1426   31    3  2017           4    17
# 1427   31    3  2017           4    11
# 1428   31    3  2017           4    15
#
# [1429 rows x 8 columns]

# %% [markdown]
# #### 6 - Coluna property_type: separar/split de informações

# %%
    # Fazer o split por hífen
property = df['property_type'].str.split('-', expand = True) # If using expand=True, Series and Index callers return DataFrame and MultiIndex objects, respectively.
    
    # Criar nova coluna (property_types, a 1ª parte do endereço)
df['property_types'] = property[0]

    # Criar nova coluna (property_detail, a 2ª parte do endereço)
df['property_details'] = property[1]

    # Conferir se tem alguma informação vazia (pq não tinha hífen) em property_types, decorrente do split

df[df['property_types'].isnull()]
        # Obs: não tem nulls        

    # Conferir se tem alguma informação vazia (pq não tinha hífen) em property_details, decorrente do split

df[df['property_details'].isnull()]
df.isnull().sum()
        # Obs: tem nulls. Existem propriedades que não têm detalhes
# Out:
# borough                0
# property_type          0
# timestamp_of_call      0
# dia                    0
# mês                    0
# ano                    0
# dia_semana             0
# hora                   0
# property_types         0
# property_details     143
# dtype: int64

# %% [markdown]
# #### 7 - Remover a coluna property_type, pois já suas informações já foram separadas

# %%
df = df.drop(['property_type'], axis = 1)

# %% [markdown]
# #### 8 - Data frame atualizado

# %%
df
# Out:
#                      borough   timestamp_of_call  dia  mês   ano  dia_semana  \
# 0     Kensington And chelsea 2017-01-01 16:48:00    1    1  2017           6
# 1                     Camden 2017-01-01 22:20:00    1    1  2017           6
# 2                  Southwark 2017-01-01 09:51:00    1    1  2017           6
# 3                Westminster 2017-01-01 00:28:00    1    1  2017           6
# 4       Barking And dagenham 2017-01-01 13:33:00    1    1  2017           6
# ...                      ...                 ...  ...  ...   ...         ...
# 1424                  Sutton 2017-03-31 14:58:00   31    3  2017           4
# 1425              Hillingdon 2017-03-31 22:41:00   31    3  2017           4
# 1426    Richmond Upon thames 2017-03-31 17:01:00   31    3  2017           4
# 1427                Hounslow 2017-03-31 11:14:00   31    3  2017           4
# 1428                  Bexley 2017-03-31 15:18:00   31    3  2017           4
#
#       hora                    property_types   property_details
# 0       16  Purpose Built Flats/Maisonettes      4 to 9 storeys
# 1       22  Purpose Built Flats/Maisonettes      4 to 9 storeys
# 2        9  Purpose Built Flats/Maisonettes      4 to 9 storeys
# 3        0  Purpose Built Flats/Maisonettes      4 to 9 storeys
# 4       13                            House    single occupancy
# ...    ...                               ...                ...
# 1424    14                            House    single occupancy
# 1425    22                            House    single occupancy
# 1426    17  Purpose Built Flats/Maisonettes     Up to 3 storeys
# 1427    11        Converted Flat/Maisonette     Up to 2 storeys
# 1428    15  Self contained Sheltered Housing               None
#
# [1429 rows x 9 columns]
